# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('full data.csv')
data
# Out:
#                       Galaxy Name      m-M    err      D         Method  \
# 0                             NaN    (mag)  (mag)  (Mpc)            NaN
# 1                              -1       -2     -3     -4             -5
# 2                      UGC 12914     33.57    0.2   51.8        Sosies
# 3                             WLM     25.1   0.15   1.05      Cepheids
# 4                             WLM    24.92   0.21  0.964      Cepheids
# 5                             WLM    24.75    0.1  0.891           TRGB
# 6                             WLM    24.77   0.09  0.899          TRGB
# 7                             WLM    24.85   0.08  0.932          TRGB
# 8                             WLM    25.88    ...    1.5  Tully-Fisher
# 9                             WLM    24.88   0.09  0.946            CMD
# 10                            WLM    24.95   0.13  0.977            CMD
# 11                       NGC 7814    30.44   0.14   12.2           SBF
# ...
